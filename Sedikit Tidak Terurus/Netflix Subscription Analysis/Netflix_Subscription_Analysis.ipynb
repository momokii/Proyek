# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

# %%
data = pd.read_csv("netflix_price.csv")
data
# Out:
#           Country  Total Library Size  No. of TV Shows  No. of Movies  \
# 0       Argentina                4760             3154           1606
# 1         Austria                5640             3779           1861
# 2         Bolivia                4991             3155           1836
# 3        Bulgaria                6797             4819           1978
# 4           Chile                4994             3156           1838
# ..            ...                 ...              ...            ...
# 60        Ireland                6486             4515           1971
# 61    Switzerland                5506             3654           1852
# 62      Australia                6114             4050           2064
# 63        Denmark                4558             2978           1580
# 64  United States                5818             3826           1992
#
#     Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# 0                         3.74                           6.30
# ...

# %%
data.Country.to_list()
# Out:
# ['Argentina',
#  'Austria',
#  'Bolivia',
#  'Bulgaria',
#  'Chile',
#  'Colombia',
#  'Costa Rica',
#  'Croatia',
#  'Czechia',
#  'Ecuador',
#  'Estonia',
#  'France',
#  'Germany',
#  'Gibraltar',
#  'Greece',
#  'Guatemala',
#  'Honduras',
#  'Hong Kong',
#  'Iceland',
#  'India',
#  'Israel',
#  'Italy',
#  'Japan',
#  'Liechtenstein',
#  'Malaysia',
#  'Mexico',
#  'Moldova',
#  'Monaco',
#  'Norway',
#  'Paraguay',
#  'Peru',
#  'Philippines',
#  'Poland',
#  'Romania',
#  'Russia',
#  'San Marino',
#  'Slovakia',
#  'South Africa',
#  'South Korea',
#  'Taiwan',
#  'Thailand',
#  'Turkey',
#  'Ukraine',
#  'Uruguay',
#  'Venezuela',
#  'Belgium',
#  'Singapore',
#  'Finland',
#  'Latvia',
#  'New Zealand',
#  'Hungary',
#  'Portugal',
#  'Netherlands',
#  'Sweden',
#  'Canada',
#  'Lithuania',
#  'Spain',
#  'United Kingdom',
#  'Indonesia',
#  'Brazil',
#  'Ireland',
#  'Switzerland',
#  'Australia',
#  'Denmark',
#  'United States']

# %%
data.columns
# Out:
# Index(['Country', 'Total Library Size', 'No. of TV Shows', 'No. of Movies',
#        'Cost Per Month - Basic ($)', 'Cost Per Month - Standard ($)',
#        'Cost Per Month - Premium ($)'],
#       dtype='object')

# %%
data.shape
# Out:
# (65, 7)

# %%
col = ["Country", "Library_size", "Tv_shows", "Movies", "Basic_month_cost", "Standar_month_cost", "Premium_month_cost"]

data.columns = col

# %%
data
# Out:
#           Country  Library_size  Tv_shows  Movies  Basic_month_cost  \
# 0       Argentina          4760      3154    1606              3.74
# 1         Austria          5640      3779    1861              9.03
# 2         Bolivia          4991      3155    1836              7.99
# 3        Bulgaria          6797      4819    1978              9.03
# 4           Chile          4994      3156    1838              7.07
# ..            ...           ...       ...     ...               ...
# 60        Ireland          6486      4515    1971              9.03
# 61    Switzerland          5506      3654    1852             12.88
# 62      Australia          6114      4050    2064              7.84
# 63        Denmark          4558      2978    1580             12.00
# 64  United States          5818      3826    1992              8.99
#
#     Standar_month_cost  Premium_month_cost
# 0                 6.30                9.26
# 1                14.67               20.32
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             65 non-null     object
#  1   Library_size        65 non-null     int64
#  2   Tv_shows            65 non-null     int64
#  3   Movies              65 non-null     int64
#  4   Basic_month_cost    65 non-null     float64
#  5   Standar_month_cost  65 non-null     float64
#  6   Premium_month_cost  65 non-null     float64
# dtypes: float64(3), int64(3), object(1)
# memory usage: 3.7+ KB

# %%
data.isna().sum()
# Out:
# Country               0
# Library_size          0
# Tv_shows              0
# Movies                0
# Basic_month_cost      0
# Standar_month_cost    0
# Premium_month_cost    0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.set_index("Country", inplace = True)

# %%
data
# Out:
#                Library_size  Tv_shows  Movies  Basic_month_cost  \
# Country
# Argentina              4760      3154    1606              3.74
# Austria                5640      3779    1861              9.03
# Bolivia                4991      3155    1836              7.99
# Bulgaria               6797      4819    1978              9.03
# Chile                  4994      3156    1838              7.07
# ...                     ...       ...     ...               ...
# Ireland                6486      4515    1971              9.03
# Switzerland            5506      3654    1852             12.88
# Australia              6114      4050    2064              7.84
# Denmark                4558      2978    1580             12.00
# United States          5818      3826    1992              8.99
#
#                Standar_month_cost  Premium_month_cost
# Country
# Argentina                    6.30                9.26
# Austria                     14.67               20.32
# ...

# %%
data.describe()
# Out:
#        Library_size     Tv_shows       Movies  Basic_month_cost  \
# count     65.000000    65.000000    65.000000         65.000000
# mean    5314.415385  3518.953846  1795.461538          8.368462
# std      980.322633   723.010556   327.279748          1.937819
# min     2274.000000  1675.000000   373.000000          1.970000
# 25%     4948.000000  3154.000000  1628.000000          7.990000
# 50%     5195.000000  3512.000000  1841.000000          8.990000
# 75%     5952.000000  3832.000000  1980.000000          9.030000
# max     7325.000000  5234.000000  2387.000000         12.880000
#
#        Standar_month_cost  Premium_month_cost
# count           65.000000           65.000000
# mean            11.990000           15.612923
# std              2.863979            4.040672
# min              3.000000            4.020000
# 25%             10.710000           13.540000
# 50%             11.490000           14.450000
# 75%             13.540000           18.060000
# ...

# %%
data.skew()
# Out:
# Library_size         -0.727561
# Tv_shows             -0.042124
# Movies               -2.014921
# Basic_month_cost     -0.968166
# Standar_month_cost    0.040069
# Premium_month_cost    0.288341
# dtype: float64

# %%
data.kurt()
# Out:
# Library_size          1.650905
# Tv_shows              0.538214
# Movies                6.688061
# Basic_month_cost      2.821351
# Standar_month_cost    2.285208
# Premium_month_cost    1.059064
# dtype: float64

# %%
data.plot(subplots = True, kind = "kde", figsize = (15, 24), sharex = False, fontsize = 20)
plt.show()

# %%
data.corr()
# Out:
#                     Library_size  Tv_shows    Movies  Basic_month_cost  \
# Library_size            1.000000  0.971146  0.849957         -0.062877
# Tv_shows                0.971146  1.000000  0.699786         -0.003814
# Movies                  0.849957  0.699786  1.000000         -0.179913
# Basic_month_cost       -0.062877 -0.003814 -0.179913          1.000000
# Standar_month_cost     -0.055200  0.002285 -0.170391          0.898535
# Premium_month_cost     -0.071521 -0.011100 -0.189711          0.820914
#
#                     Standar_month_cost  Premium_month_cost
# Library_size                 -0.055200           -0.071521
# Tv_shows                      0.002285           -0.011100
# Movies                       -0.170391           -0.189711
# Basic_month_cost              0.898535            0.820914
# Standar_month_cost            1.000000            0.978768
# Premium_month_cost            0.978768            1.000000

# %%
data.corr().Library_size.sort_values(ascending = False)
# Out:
# Library_size          1.000000
# Tv_shows              0.971146
# Movies                0.849957
# Standar_month_cost   -0.055200
# Basic_month_cost     -0.062877
# Premium_month_cost   -0.071521
# Name: Library_size, dtype: float64

# %%
plt.figure(figsize = (15,8))
sns.set(font_scale = 1.5)
sns.heatmap(data.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
print(f"{(data.Tv_shows / data.Library_size).mean()} %")
# Out:
# 0.6616150185847931 %

# %%
sns.jointplot(data = data, x = data.Tv_shows, y = data.Movies, kind = "hist", height= 8)

# %%
data
# Out:
#                Library_size  Tv_shows  Movies  Basic_month_cost  \
# Country
# Argentina              4760      3154    1606              3.74
# Austria                5640      3779    1861              9.03
# Bolivia                4991      3155    1836              7.99
# Bulgaria               6797      4819    1978              9.03
# Chile                  4994      3156    1838              7.07
# ...                     ...       ...     ...               ...
# Ireland                6486      4515    1971              9.03
# Switzerland            5506      3654    1852             12.88
# Australia              6114      4050    2064              7.84
# Denmark                4558      2978    1580             12.00
# United States          5818      3826    1992              8.99
#
#                Standar_month_cost  Premium_month_cost
# Country
# Argentina                    6.30                9.26
# Austria                     14.67               20.32
# ...

# %%
data["mean_price"] = ((data.Basic_month_cost + data.Standar_month_cost + data.Premium_month_cost) / 3).round(2)
data.head()
# Out:
#            Library_size  Tv_shows  Movies  Basic_month_cost  \
# Country
# Argentina          4760      3154    1606              3.74
# Austria            5640      3779    1861              9.03
# Bolivia            4991      3155    1836              7.99
# Bulgaria           6797      4819    1978              9.03
# Chile              4994      3156    1838              7.07
#
#            Standar_month_cost  Premium_month_cost  mean_price
# Country
# Argentina                6.30                9.26        6.43
# Austria                 14.67               20.32       14.67
# Bolivia                 10.99               13.99       10.99
# Bulgaria                11.29               13.54       11.29
# Chile                    9.91               12.74        9.91

# %%
data["cat_price"] = pd.qcut(data.mean_price, [0, 0.25, 0.75, 0.9, 1], labels= ["cheap", "normal", "high", "very_high"])
data.head()
# Out:
#            Library_size  Tv_shows  Movies  Basic_month_cost  \
# Country
# Argentina          4760      3154    1606              3.74
# Austria            5640      3779    1861              9.03
# Bolivia            4991      3155    1836              7.99
# Bulgaria           6797      4819    1978              9.03
# Chile              4994      3156    1838              7.07
#
#            Standar_month_cost  Premium_month_cost  mean_price cat_price
# Country
# Argentina                6.30                9.26        6.43     cheap
# Austria                 14.67               20.32       14.67      high
# Bolivia                 10.99               13.99       10.99    normal
# Bulgaria                11.29               13.54       11.29    normal
# Chile                    9.91               12.74        9.91     cheap

# %%
data.sort_values("mean_price", ascending  = False).head(10)
# Out:
#                Library_size  Tv_shows  Movies  Basic_month_cost  \
# Country
# Switzerland            5506      3654    1852             12.88
# Liechtenstein          3048      1712    1336             12.88
# Denmark                4558      2978    1580             12.00
# Belgium                4990      3374    1616             10.16
# France                 5445      3604    1841             10.16
# Israel                 5713      3650    2063             10.56
# Sweden                 4361      2973    1388             10.90
# Iceland                6387      4426    1961              9.03
# Italy                  5183      3545    1638              9.03
# San Marino             2310      1937     373              9.03
#
#                Standar_month_cost  Premium_month_cost  mean_price  cat_price
# Country
# Switzerland                 20.46               26.96       20.10  very_high
# Liechtenstein               20.46               26.96       20.10  very_high
# ...

# %%
data.sort_values("mean_price").head(10)
# Out:
#               Library_size  Tv_shows  Movies  Basic_month_cost  \
# Country
# Turkey                4639      2930    1709              1.97
# India                 5843      3718    2125              2.64
# Argentina             4760      3154    1606              3.74
# Colombia              4991      3156    1835              4.31
# Brazil                4972      3162    1810              4.61
# Ukraine               5336      3261    2075              5.64
# Peru                  4986      3155    1831              6.11
# Philippines           6362      4154    2208              7.35
# South Africa          5736      3686    2050              6.26
# Chile                 4994      3156    1838              7.07
#
#               Standar_month_cost  Premium_month_cost  mean_price cat_price
# Country
# Turkey                      3.00                4.02        3.00     cheap
# India                       6.61                8.60        5.95     cheap
# ...

# %%
data["Library_rank"] = data.Library_size.rank(ascending = False)
data["tvShows_rank"] = data.Tv_shows.rank(ascending = False)
data["Movies_rank"] = data.Movies.rank(ascending = False)
data["mean_price_rank"] = data.mean_price.rank(ascending = False, method = "min")

# %%
data["Library_cat"] = pd.qcut(data.Library_size, [0, 0.25, 0.75, 0.9, 1], ["less", "avg", "abv_avg", "many"])

# %%
data.head()
# Out:
#            Library_size  Tv_shows  Movies  Basic_month_cost  \
# Country
# Argentina          4760      3154    1606              3.74
# Austria            5640      3779    1861              9.03
# Bolivia            4991      3155    1836              7.99
# Bulgaria           6797      4819    1978              9.03
# Chile              4994      3156    1838              7.07
#
#            Standar_month_cost  Premium_month_cost  mean_price cat_price  \
# Country
# Argentina                6.30                9.26        6.43     cheap
# Austria                 14.67               20.32       14.67      high
# Bolivia                 10.99               13.99       10.99    normal
# Bulgaria                11.29               13.54       11.29    normal
# Chile                    9.91               12.74        9.91     cheap
#
#            Library_rank  tvShows_rank  Movies_rank  mean_price_rank  \
# Country
# Argentina          54.0          49.0         52.0             63.0
# ...

# %%
data["different_basic_and_premium"] = data.Premium_month_cost - data.Basic_month_cost

# %%
data.cat_price.value_counts()
# Out:
# normal       32
# cheap        17
# high          9
# very_high     7
# Name: cat_price, dtype: int64

# %%
data.iloc[:, [3,4,5,13, 7]].sort_values("different_basic_and_premium", ascending = False).head(10)
# Out:
#                Basic_month_cost  Standar_month_cost  Premium_month_cost  \
# Country
# Liechtenstein             12.88               20.46               26.96
# Switzerland               12.88               20.46               26.96
# Gibraltar                  9.03               14.67               20.32
# Italy                      9.03               14.67               20.32
# Iceland                    9.03               14.67               20.32
# Austria                    9.03               14.67               20.32
# San Marino                 9.03               14.67               20.32
# Germany                    9.03               14.67               20.32
# Spain                      9.03               14.67               20.32
# Ireland                    9.03               14.67               20.32
#
#                different_basic_and_premium  cat_price
# Country
# Liechtenstein                        14.08  very_high
# ...

# %%
data.iloc[:, [3,4,5,13, 7]].sort_values("different_basic_and_premium").head(10)
# Out:
#              Basic_month_cost  Standar_month_cost  Premium_month_cost  \
# Country
# Turkey                   1.97                3.00                4.02
# Philippines              7.35                9.14               10.93
# Hong Kong                8.08               10.00               11.93
# Thailand                 8.34               10.43               12.52
# Taiwan                   9.74               11.90               14.07
# Romania                  9.03               11.29               13.54
# Croatia                  9.03               11.29               13.54
# Slovakia                 9.03               11.29               13.54
# Estonia                  9.03               11.29               13.54
# Lithuania                9.03               11.29               13.54
#
#              different_basic_and_premium cat_price
# Country
# Turkey                              2.05     cheap
# Philippines                         3.58     cheap
# ...

# %%
# PLOTTING MELIHAT KORELASI YANG ADA

# %%
plt.figure(figsize = (16,8))
sns.regplot(data = data, x = data.Standar_month_cost, y = data.mean_price, color= "red")
plt.title("scatterplot harga standar dan harga rata rata")
# Out:
# Text(0.5, 1.0, 'scatterplot harga standar dan harga rata rata')

# %%
plt.figure(figsize = (16, 7))
sns.countplot(data = data, hue = data.Library_cat, x = data.cat_price)
# Out:
# <AxesSubplot:xlabel='cat_price', ylabel='count'>

# %%
data.loc[(data.cat_price == "normal") & (data.Library_cat == "many")]
# Out:
#                 Library_size  Tv_shows  Movies  Basic_month_cost  \
# Country
# Bulgaria                6797      4819    1978              9.03
# Czechia                 7325      5234    2091              8.83
# Slovakia                7035      5055    1980              9.03
# Lithuania               6462      4490    1972              9.03
# United Kingdom          6643      4551    2092              7.91
#
#                 Standar_month_cost  Premium_month_cost  mean_price cat_price  \
# Country
# Bulgaria                     11.29               13.54       11.29    normal
# Czechia                      11.49               14.15       11.49    normal
# Slovakia                     11.29               13.54       11.29    normal
# Lithuania                    11.29               13.54       11.29    normal
# United Kingdom               13.20               18.48       13.20    normal
#
#                 Library_rank  tvShows_rank  Movies_rank  mean_price_rank  \
# Country
# ...

# %%
data.loc[(data.cat_price == "cheap") & (data.Library_cat == "many")]
# Out:
#          Library_size  Tv_shows  Movies  Basic_month_cost  Standar_month_cost  \
# Country
# Hungary          6884      4802    2082              7.64               10.71
#
#          Premium_month_cost  mean_price cat_price  Library_rank  tvShows_rank  \
# Country
# Hungary               13.78       10.71     cheap           3.0           4.0
#
#          Movies_rank  mean_price_rank Library_cat  different_basic_and_premium
# Country
# Hungary          9.0             50.0        many                         6.14

# %%
plt.figure(figsize = (15, 10))
sns.violinplot(data = data, x = data.Library_cat, y = data.mean_price, size=15)
# Out:
# <AxesSubplot:xlabel='Library_cat', ylabel='mean_price'>

# %%
data_rank = data[['Library_rank', 'tvShows_rank', 'Movies_rank', "mean_price_rank"]]
data_rank.head()
# Out:
#            Library_rank  tvShows_rank  Movies_rank  mean_price_rank
# Country
# Argentina          54.0          49.0         52.0             63.0
# Austria            25.0          21.5         28.5              8.0
# Bolivia            41.5          44.5         36.5             43.0
# Bulgaria            4.0           3.0         18.0             35.0
# Chile              38.0          41.5         34.0             56.0

# %%
plt.figure(figsize = (16, 12))
sns.heatmap(data_rank.sort_values(["mean_price_rank", 'Library_rank', 'tvShows_rank', 'Movies_rank']).iloc[:10], 
            annot = True)
# Out:
# <AxesSubplot:ylabel='Country'>

# %%
plt.figure(figsize = (16, 12))
sns.heatmap(data_rank.sort_values(['Library_rank', 'tvShows_rank', 'Movies_rank']).iloc[:10], 
            annot = True)
# Out:
# <AxesSubplot:ylabel='Country'>

# %%
data
# Out:
#                Library_size  Tv_shows  Movies  Basic_month_cost  \
# Country
# Argentina              4760      3154    1606              3.74
# Austria                5640      3779    1861              9.03
# Bolivia                4991      3155    1836              7.99
# Bulgaria               6797      4819    1978              9.03
# Chile                  4994      3156    1838              7.07
# ...                     ...       ...     ...               ...
# Ireland                6486      4515    1971              9.03
# Switzerland            5506      3654    1852             12.88
# Australia              6114      4050    2064              7.84
# Denmark                4558      2978    1580             12.00
# United States          5818      3826    1992              8.99
#
#                Standar_month_cost  Premium_month_cost  mean_price  cat_price  \
# Country
# Argentina                    6.30                9.26        6.43      cheap
# ...

# %%
data.sort_values("different_basic_and_premium", ascending = False).head(10)
# Out:
#                Library_size  Tv_shows  Movies  Basic_month_cost  \
# Country
# Liechtenstein          3048      1712    1336             12.88
# Switzerland            5506      3654    1852             12.88
# Gibraltar              6167      4079    2088              9.03
# Italy                  5183      3545    1638              9.03
# Iceland                6387      4426    1961              9.03
# Austria                5640      3779    1861              9.03
# San Marino             2310      1937     373              9.03
# Germany                5668      3814    1854              9.03
# Spain                  5229      3536    1693              9.03
# Ireland                6486      4515    1971              9.03
#
#                Standar_month_cost  Premium_month_cost  mean_price  cat_price  \
# Country
# Liechtenstein               20.46               26.96       20.10  very_high
# Switzerland                 20.46               26.96       20.10  very_high
# ...

# %%
data.different_basic_and_premium.head(10)
# Out:
# Country
# Argentina      5.52
# Austria       11.29
# Bolivia        6.00
# Bulgaria       4.51
# Chile          5.67
# Colombia       5.62
# Costa Rica     7.00
# Croatia        4.51
# Czechia        5.32
# Ecuador        6.00
# Name: different_basic_and_premium, dtype: float64

# %%
data.loc[:, [ 'Basic_month_cost', 'Standar_month_cost', 'Premium_month_cost', 
             'different_basic_and_premium', 'cat_price']].sort_values("different_basic_and_premium",
                                                                      ascending = False).head(10)
# Out:
#                Basic_month_cost  Standar_month_cost  Premium_month_cost  \
# Country
# Liechtenstein             12.88               20.46               26.96
# Switzerland               12.88               20.46               26.96
# Gibraltar                  9.03               14.67               20.32
# Italy                      9.03               14.67               20.32
# Iceland                    9.03               14.67               20.32
# Austria                    9.03               14.67               20.32
# San Marino                 9.03               14.67               20.32
# Germany                    9.03               14.67               20.32
# Spain                      9.03               14.67               20.32
# Ireland                    9.03               14.67               20.32
#
#                different_basic_and_premium  cat_price
# Country
# Liechtenstein                        14.08  very_high
# ...
